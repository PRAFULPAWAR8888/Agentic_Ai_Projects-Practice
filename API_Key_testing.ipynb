# %% [markdown]
# <a href="https://colab.research.google.com/github/PRAFULPAWAR8888/Agentic_Ai_Projects-Practice/blob/main/API_Key_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os
userdata.get('GOOGLE_API_KEY')
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
from openai import OpenAI

# %%
client = OpenAI(
    api_key=userdata.get('GOOGLE_API_KEY'),
    base_url="https://generativelanguage.googleapis.com/v1beta"
)

# %%
response = client.chat.completions.create(
    model="gemini-2.0-flash",
    messages=[
        {"role": "user", "content": "Hello! This is a test using OpenAI SDK with Google API key."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Okay! I understand. You're testing the OpenAI SDK using a Google API key.
#
# I'm ready. How can I help you with your test?  Do you want me to:
#
# *   **Generate text based on a prompt you provide?**
# *   **Translate something?**
# *   **Summarize something?**
# *   **Answer a question?**
# *   **Just confirm that the setup is working? (If so, tell me what API endpoint you're using and I can try a simple request)**
#
# Let me know what you'd like me to do to assist you in your test.  Good luck!
